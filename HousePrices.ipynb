# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#correlation matrix
colors= ['#5433FF', '#20BDFF', '#A5FECB']
palette = sns.set_palette(sns.color_palette(colors, as_cmap = True))
sns.palplot(sns.color_palette(colors))
k = 11
cols = df.corr().nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
plt.figure(figsize=[10, 8])
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', cmap=colors, annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)

# %%
#checking for normal distribution
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt', 'YearRemodAdd']
sns.pairplot(df[cols], size = 2.5)
plt.show()

# %%
print("Skewness: ", df['SalePrice'].skew())
print("Kurtosis: ", df['SalePrice'].kurt())
# Out:
# Skewness:  1.8828757597682129
# Kurtosis:  6.536281860064529

# %%
#log transformation
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt', 'YearRemodAdd']
sns.pairplot(np.log1p(df[cols]), size = 2.5)
plt.show()

# %%
#checking for reduced skewness and kurtosis
print("Skewness: ", np.log1p(df['SalePrice']).skew())
print("Kurtosis: ", np.log1p(df['SalePrice']).kurt())
# Out:
# Skewness:  0.12134661989685333
# Kurtosis:  0.809519155707878

# %%
#check for multicollinearity
corr = df.corr()
plt.figure(figsize=(25,25))
sns.heatmap(corr, annot = True)
plt.show()

# %%
#checking for multicollinearity and dropping the column in each subset having lesser correlation with target variable
df.drop(columns = ['PoolArea','GarageCond','GarageFinish', 'Functional','GarageYrBlt', 'TotRmsAbvGrd','BsmtFinType2','1stFlrSF'], inplace = True, axis = 1)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...           0    NaN   NaN         NaN       0
# 1         Lvl    AllPub  ...           0    NaN   NaN         NaN       0
# 2         Lvl    AllPub  ...           0    NaN   NaN         NaN       0
# 3         Lvl    AllPub  ...           0    NaN   NaN         NaN       0
# 4         Lvl    AllPub  ...           0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#missing values
missing = df.isna()
percent = (missing.sum()/missing.count()*100).sort_values(ascending=False)
missing_columns = percent[percent > 0].index.tolist()
df.drop(missing_columns, axis=1, inplace=True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    Inside       Gtl  ...          61             0         0           0
# 1       FR2       Gtl  ...           0             0         0           0
# 2    Inside       Gtl  ...          42             0         0           0
# 3    Corner       Gtl  ...          35           272         0           0
# 4       FR2       Gtl  ...          84             0         0           0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
#finding numeric columns 
num_col=df._get_numeric_data().columns.tolist()
num_col
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
cat_col=set(df.columns)-set(num_col)
cat_col
# Out:
# {'BldgType',
#  'CentralAir',
#  'Condition1',
#  'Condition2',
#  'ExterCond',
#  'ExterQual',
#  'Exterior1st',
#  'Exterior2nd',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'HouseStyle',
#  'KitchenQual',
#  'LandContour',
#  'LandSlope',
#  'LotConfig',
#  'LotShape',
#  'MSZoning',
#  'Neighborhood',
#  'PavedDrive',
#  'RoofMatl',
#  'RoofStyle',
#  'SaleCondition',
#  'SaleType',
#  'Street',
#  'Utilities'}

# %%
#numeric columns na
for col in num_col:
    df[col].fillna(df[col].mean(),inplace=True)

# %%
#cat columns na
for col in cat_col:

    df[col].fillna(df[col].mode()[0],inplace=True)

# %%
for col in cat_col:
    pd.get_dummies(df[col])

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    Inside       Gtl  ...          61             0         0           0
# 1       FR2       Gtl  ...           0             0         0           0
# 2    Inside       Gtl  ...          42             0         0           0
# 3    Corner       Gtl  ...          35           272         0           0
# 4       FR2       Gtl  ...          84             0         0           0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
X=pd.get_dummies(df)
X.shape
# Out:
# (1460, 207)

# %%
#min-max scaler
scaler=StandardScaler()
X[X.columns] = scaler.fit_transform(X[X.columns])

# %%
X = X.drop(['Id'], axis = 1)

# %%
X.head()
# Out:
#    MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0    0.073375 -0.207142     0.651479    -0.517200   1.050994      0.878668
# 1   -0.872563 -0.091886    -0.071836     2.179628   0.156734     -0.429577
# 2    0.073375  0.073480     0.651479    -0.517200   0.984752      0.830215
# 3    0.309859 -0.096897     0.651479    -0.517200  -1.863632     -0.720298
# 4    0.073375  0.375148     1.374795    -0.517200   0.951632      0.733308
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  SaleType_ConLw  \
# 0    0.575425   -0.288653  -0.944591    -0.459303  ...       -0.058621
# 1    1.171992   -0.288653  -0.641228     0.466465  ...       -0.058621
# 2    0.092907   -0.288653  -0.301643    -0.313369  ...       -0.058621
# 3   -0.499274   -0.288653  -0.061670    -0.687324  ...       -0.058621
# 4    0.463568   -0.288653  -0.174865     0.199680  ...       -0.058621
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 206 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(206)
# memory usage: 2.3 MB

# %%
#numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
y = df['SalePrice']
X = X.drop(['SalePrice'],axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

#s_scaler = StandardScaler()
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)
y_train_l = np.log1p(y_train)
y_val_l = np.log1p(y_val)
#X_train = s_scaler.fit_transform(X_train.astype(np.float))
#X_val = s_scaler.transform(X_val.astype(np.float))

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train_l)
y_predicted = np.expm1(regressor.predict(X_train))
print('Train r2',(r2_score(y_train, y_predicted)))
y_predicted_val = np.expm1(regressor.predict(X_val))
print('Val r2',(r2_score(y_val, y_predicted_val)))
# Out:
# Train r2 0.9390452020320018
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-2a11bb5a2377> in <module>
#       4 print('Train r2',(r2_score(y_train, y_predicted)))
#       5 y_predicted_val = np.expm1(regressor.predict(X_val))
# ----> 6 print('Val r2',(r2_score(y_val, y_predicted_val)))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     674     -3.0
#     675     """
# --> 676     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     677         y_true, y_pred, multioutput)
# ...

# %%
#%%cmd
#jupyter nbconvert Jupyter\ HousePrices.ipynb --to slides --post serve
